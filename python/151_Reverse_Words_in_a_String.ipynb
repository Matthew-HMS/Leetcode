# %%
class Solution:
    def reverseWords(self, s: str) -> str:
        s_list = s.split()
        output = []
        for string in s_list[::-1]:
            output.append(string)
            output.append(" ")

        output.pop()

        return ''.join(output)

# %% [markdown]
# crazy!!

# %%
class Solution:
    def reverseWords(self, s: str) -> str:
        return ' '.join(s.split()[::-1])
