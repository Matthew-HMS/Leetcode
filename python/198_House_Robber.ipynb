# %%
class Solution:
    def rob(self, nums: List[int]) -> int:
        if len(nums) == 1:
            return nums[0]
        elif len(nums) == 2:
            return max(nums[0], nums[1])
        elif len(nums) == 3:
            return max(nums[0] + nums[2], nums[1])
        money = [nums[0], nums[1], nums[2] + nums[0]]
        for i in range(3, len(nums)):
            rob = max(money[i-2], money[i-3]) + nums[i]
            money.append(rob)

        return max(money[-1], money[-2])

# %% [markdown]
# Space: O(1)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:
        if len(nums) == 1:
            return nums[0]
        elif len(nums) == 2:
            return max(nums[0], nums[1])
        a, b = nums[0], max(nums[0], nums[1])
        for i in range(2, len(nums)):
            rob = max(b, a + nums[i])
            a, b = b, rob

        return max(a, b)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:
        prev_rob = max_rob = 0

        for cur_val in nums:
            temp = max(max_rob, prev_rob + cur_val)
            prev_rob = max_rob
            max_rob = temp
        
        return max_rob
